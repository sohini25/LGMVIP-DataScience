# %% [markdown]
# #  IRIS DATASET
# # Author : Sohini Chatterjee
# # Data Science Intern

# %%
# Import Libraries
import numpy as np  
import pandas as pd 

from sklearn.preprocessing import LabelEncoder 
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the data
data = pd.read_csv('/content/iris.csv')

# %%
data
# Out:
#      sepal length in cm  sepal width in cm  ...  petal width in cm         outputs
# 0                   5.1                3.5  ...                0.2     Iris-setosa
# 1                   4.9                3.0  ...                0.2     Iris-setosa
# 2                   4.7                3.2  ...                0.2     Iris-setosa
# 3                   4.6                3.1  ...                0.2     Iris-setosa
# 4                   5.0                3.6  ...                0.2     Iris-setosa
# ..                  ...                ...  ...                ...             ...
# 145                 6.7                3.0  ...                2.3  Iris-virginica
# 146                 6.3                2.5  ...                1.9  Iris-virginica
# 147                 6.5                3.0  ...                2.0  Iris-virginica
# 148                 6.2                3.4  ...                2.3  Iris-virginica
# ...

# %%
# Check first 5 records
data.head()
# Out:
#    sepal length in cm  sepal width in cm  ...  petal width in cm      outputs
# 0                 5.1                3.5  ...                0.2  Iris-setosa
# 1                 4.9                3.0  ...                0.2  Iris-setosa
# 2                 4.7                3.2  ...                0.2  Iris-setosa
# 3                 4.6                3.1  ...                0.2  Iris-setosa
# 4                 5.0                3.6  ...                0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sepal length in cm  150 non-null    float64
#  1   sepal width in cm   150 non-null    float64
#  2   petal length in cm  150 non-null    float64
#  3   petal width in cm   150 non-null    float64
#  4   outputs             150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.describe()
# Out:
#        sepal length in cm  ...  petal width in cm
# count          150.000000  ...         150.000000
# mean             5.843333  ...           1.199333
# std              0.828066  ...           0.762238
# min              4.300000  ...           0.100000
# 25%              5.100000  ...           0.300000
# 50%              5.800000  ...           1.300000
# 75%              6.400000  ...           1.800000
# max              7.900000  ...           2.500000
#
# [8 rows x 4 columns]

# %%
# check the distribution of the class 
data['outputs'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: outputs, dtype: int64

# %%
#pairplots
g= sns.pairplot(data, hue='outputs', markers='+')
plt.show()

# %%
#skewness of the IRIS dataset
data.skew()
# Out:
# sepal length in cm    0.314911
# sepal width in cm     0.318966
# petal length in cm   -0.274884
# petal width in cm    -0.102967
# dtype: float64

# %% [markdown]
# # **BOXPLOTS**

# %%
#Boxplot showing outputs and sepal length of the data
sns.boxplot(x=data['outputs'], y='sepal length in cm',data= data, palette= "Set1")
plt.show()

# %%
#Boxplot showing outputs and sepal width of the data
sns.boxplot(x=data['outputs'], y='sepal width in cm',data= data, palette= "Set1")
plt.show()

# %%
#Boxplot showing outputs and petal length of the data
sns.boxplot(x=data['outputs'], y='petal length in cm',data= data, palette= "Set1")
plt.show()

# %%
#Boxplot showing outputs and petal width of the data
sns.boxplot(x=data['outputs'], y='petal width in cm',data= data, palette= "Set1")
plt.show()

# %%
#shape of dataset
X= data.drop(['outputs'],axis=1)
y=data['outputs']
print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
#Splitting Dataset into test and train

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4 )

# %%
#training set
print(X_train.shape)
print(y_train.shape)
#testing set
print(X_test.shape)
print(y_test.shape)
# Out:
# (90, 4)
# (90,)
# (60, 4)
# (60,)

# %%
#Selecting different no of k in range [1,26] and choose the one with high accuracy

k_range = list(range(1,26))
scores = []
for i in k_range:
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))

    plt.title('Accurate scores for k values of knn')
plt.xlabel('Number of Neighbors K')
plt.ylabel('Accurate scores')
plt.plot(k_range, scores)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25 )

# %%
#training set
print(X_train.shape)
print(y_train.shape)
#testing set
print(X_test.shape)
print(y_test.shape)
# Out:
# (112, 4)
# (112,)
# (38, 4)
# (38,)

# %%
#Selecting different no of k in range [1,26] and choose the one with high accuracy

k_range = list(range(1,26))
scores = []
for i in k_range:
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))

    plt.title('Accurate scores for k values of knn')
plt.xlabel('Number of Neighbors K')
plt.ylabel('Accurate scores')
plt.plot(k_range, scores)
plt.show()

# %%
knn= knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train,y_train)
knn.predict([[6.2,2.1,6.9,2.8]])
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score

# Instantiate learning model (k = 13)
classifier = KNeighborsClassifier(n_neighbors=3)

# Fitting the model
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
#confusion matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[11,  0,  0],
#        [ 0, 12,  2],
#        [ 0,  0, 13]])

# %%
accuracy = accuracy_score(y_test, y_pred)*100
print('Accuracy of our model is equal ' + str(round(accuracy, 2)) + ' %.')
# Out:
# Accuracy of our model is equal 94.74 %.

# %% [markdown]
# # **THANK** **YOU**
